csv')
time = [x[:10]+' '+x[11:19] for x in df['2'].values]
df['time'] = time
df['time'] = pd.to_datetime(df['time'])
df = df.set_index('time')
df = df.sort_index()
df = df.drop(columns=['Unnamed: 0','0','1','2','3'])
df = df[df > 0]
df = df.resample('5T', label = 'right').mean()
df_c9 = df.dropna()

df_c9.head()
# Out:
#                           0         1         2         3         4    \
# time
# 2020-01-01 00:05:00  6.276217  6.276217  6.253678  6.276217  6.276217
# 2020-01-01 00:10:00  6.343834  6.343834  6.298756  6.253678  6.253678
# 2020-01-01 00:15:00  6.388913  6.388913  6.366374  6.321295  6.321295
# 2020-01-01 00:20:00  6.366374  6.366374  6.366374  6.388913  6.388913
# 2020-01-01 00:25:00  6.411452  6.411452  6.388913  6.388913  6.388913
#
#                           5         6         7         8         9    ...  \
# time                                                                   ...
# 2020-01-01 00:05:00  6.298756  6.343834  6.411452  6.411452  6.433991  ...
# 2020-01-01 00:10:00  6.208600  6.231139  6.253678  6.253678  6.298756  ...
# 2020-01-01 00:15:00  6.231139  6.163522  6.140983  6.140983  6.186061  ...
# 2020-01-01 00:20:00  6.366374  6.321295  6.253678  6.253678  6.208600  ...
# 2020-01-01 00:25:00  6.388913  6.388913  6.388913  6.388913  6.366374  ...
#
#                           431       432       433       434       435  \
# time
# 2020-01-01 00:05:00  6.997468  6.997468  6.997468  6.997468  6.997468
# 2020-01-01 00:10:00  6.997468  6.997468  6.974929  6.974929  6.974929
# 2020-01-01 00:15:00  7.042547  7.020008  6.997468  6.997468  6.997468
# 2020-01-01 00:20:00  7.042547  7.020008  7.020008  7.020008  7.020008
# 2020-01-01 00:25:00  7.065086  7.065086  7.042547  7.042547  7.042547
#
#                           436       437       438       439       440
# time
# 2020-01-01 00:05:00  6.997468  6.997468  7.020008  6.997468  6.997468
# 2020-01-01 00:10:00  6.952390  6.952390  6.952390  6.929851  6.929851
# 2020-01-01 00:15:00  6.974929  6.974929  6.952390  6.929851  6.952390
# 2020-01-01 00:20:00  7.020008  7.020008  6.974929  6.952390  6.974929
# 2020-01-01 00:25:00  7.042547  7.042547  6.997468  6.997468  7.020008
#
# [5 rows x 441 columns]

# %%
df = pd.read_csv('bon_2020_c11.csv')
time = [x[:10]+' '+x[11:19] for x in df['2'].values]
df['time'] = time
df['time'] = pd.to_datetime(df['time'])
df = df.set_index('time')
df = df.sort_index()
df = df.drop(columns=['Unnamed: 0','0','1','2','3'])
df = df[df > 0]
df = df.resample('5T', label = 'right').mean()
df_c11 = df.dropna()

df_c11.head()
# Out:
#                            0          1          2          3          4    \
# time
# 2020-01-01 00:05:00  25.283960  25.283960  24.950382  24.716877  24.716877
# 2020-01-01 00:10:00  27.085279  27.085279  26.051189  25.117170  25.117170
# 2020-01-01 00:15:00  29.420326  29.420326  29.186821  28.286161  28.286161
# 2020-01-01 00:20:00  29.653830  29.653830  30.320986  30.487776  30.487776
# 2020-01-01 00:25:00  29.453684  29.453684  29.853977  30.320986  30.320986
#
#                            5          6          7          8          9    \
# time
# 2020-01-01 00:05:00  25.117170  25.650896  26.117905  26.117905  26.551556
# 2020-01-01 00:10:00  24.716877  24.149796  24.283226  24.283226  25.117170
# 2020-01-01 00:15:00  26.551556  24.583447  24.083078  24.083078  24.550089
# 2020-01-01 00:20:00  30.187555  28.719812  26.651628  26.651628  25.317318
# 2020-01-01 00:25:00  30.621206  30.754639  31.188290  31.188290  30.621206
#
#                      ...        431        432        433        434  \
# time                 ...
# 2020-01-01 00:05:00  ...  28.386234  28.319519  28.252804  28.252804
# 2020-01-01 00:10:00  ...  28.186087  28.219446  28.252804  28.252804
# 2020-01-01 00:15:00  ...  28.152729  28.086014  27.919226  27.919226
# 2020-01-01 00:20:00  ...  28.252804  28.152729  28.086014  28.086014
# 2020-01-01 00:25:00  ...  28.386234  28.352877  28.252804  28.252804
#
#                            435        436        437        438        439  \
# time
# 2020-01-01 00:05:00  28.386234  28.553022  28.553022  28.553022  28.619740
# 2020-01-01 00:10:00  28.352877  28.619740  28.619740  28.486307  28.352877
# 2020-01-01 00:15:00  28.086014  28.386234  28.386234  28.286161  28.186087
# 2020-01-01 00:20:00  28.119371  28.019299  28.019299  27.819151  27.619005
# 2020-01-01 00:25:00  28.252804  28.186087  28.186087  28.019299  27.785793
#
#                            440
# time
# 2020-01-01 00:05:00  28.753170
# 2020-01-01 00:10:00  28.352877
# 2020-01-01 00:15:00  28.319519
# 2020-01-01 00:20:00  27.785793
# 2020-01-01 00:25:00  27.619005
#
# [5 rows x 441 columns]

# %%
c_index = [index for index in df_c1.index if index in df_c3.index and index in df_c4.index and index in df_c5.index and index in df_c6.index and index in df_c7.index and index in df_c9.index and index in df_c11.index]
len(c_index)
# Out:
# 44680

# %%
df_ghi = pd.read_csv('bon_ghics_2020.csv')
df_ghi['time'] = pd.to_datetime(df_ghi['time'])
df_ghi = df_ghi.set_index('time')
df_ghi = df_ghi[df_ghi['ghi'] > 0]
df_ghi['CSI'] = df_ghi['ghi']/df_ghi['ghics_nsrdb']
df_ghi.head()
# Out:
#                      ghics_pvlib    ghics_tl   ghics_tla     ghi    zen  \
# time
# 2020-01-01 15:50:00   328.551397  327.419917  333.794446  347.92  69.61
# 2020-01-01 15:55:00   338.063247  336.924446  343.339106  357.34  69.12
# 2020-01-01 16:00:00   347.243301  346.097706  352.549600  365.98  68.66
# 2020-01-01 16:05:00   356.084862  354.932962  361.419405  374.50  68.20
# 2020-01-01 16:10:00   364.581653  363.423902  369.942400  383.04  67.77
#
#                      dw_solar    GHI  ghics_rest  ghics_mc       CSI
# time
# 2020-01-01 15:50:00    347.92  359.0       359.0  363.2448  0.969136
# 2020-01-01 15:55:00    357.34  369.0       369.0  373.0872  0.968401
# 2020-01-01 16:00:00    365.98  378.0       378.0  382.5876  0.968201
# 2020-01-01 16:05:00    374.50  387.0       387.0  391.7388  0.967700
# 2020-01-01 16:10:00    383.04  395.0       395.0  400.5348  0.969722

# %%
train_months = [1,2,4,5,7,8,10,11]
#valid_months = []
test_months = [3,6,9,12]
train_index = [index for index in df_ghi.index if index.month in train_months]
test_index = [index for index in df_ghi.index if index.month in test_months]
len(train_index),len(test_index),len(train_index)+len(test_index),df_ghi.shape[0]
# Out:
# (17220, 5479, 22699, 22699)

# %%
tr_index = train_index 
te_index = test_index 
len(tr_index),len(te_index)
# Out:
# (17220, 5479)

# %%
# select the time indexes for training and testing
index_ = []
all_index = tr_index + te_index
for index in all_index:
    if index in c_index and (index - datetime.timedelta(minutes=5) in c_index 
        and index - datetime.timedelta(minutes=10) in c_index
        and index - datetime.timedelta(minutes=15) in c_index
        and index - datetime.timedelta(minutes=20) in c_index 
        and index - datetime.timedelta(minutes=25) in c_index 
        and index - datetime.timedelta(minutes=30) in c_index
        and index - datetime.timedelta(minutes=35) in c_index 
        and index - datetime.timedelta(minutes=40) in c_index
        and index - datetime.timedelta(minutes=45) in c_index 
        and index - datetime.timedelta(minutes=50) in c_index
        and index - datetime.timedelta(minutes=55) in c_index 
        and index - datetime.timedelta(minutes=60) in c_index
        and index + datetime.timedelta(minutes=15) in all_index 
        and index + datetime.timedelta(minutes=30) in all_index
        and index + datetime.timedelta(minutes=45) in all_index 
        and index + datetime.timedelta(minutes=60) in all_index
        and index + datetime.timedelta(minutes=90) in all_index 
        and index + datetime.timedelta(minutes=120) in all_index
        and index + datetime.timedelta(minutes=150) in all_index 
        and index + datetime.timedelta(minutes=180) in all_index
                            ):
        index_.append(index)
len(index_)
# Out:
# 5104

# %%
tr_index_00 = [index for index in index_ if index in tr_index]

tr_index_60 = [index - datetime.timedelta(minutes=60) for index in tr_index_00]
tr_index_55 = [index - datetime.timedelta(minutes=55) for index in tr_index_00]
tr_index_50 = [index - datetime.timedelta(minutes=50) for index in tr_index_00]
tr_index_45 = [index - datetime.timedelta(minutes=45) for index in tr_index_00]
tr_index_40 = [index - datetime.timedelta(minutes=40) for index in tr_index_00]
tr_index_35 = [index - datetime.timedelta(minutes=35) for index in tr_index_00]
tr_index_30 = [index - datetime.timedelta(minutes=30) for index in tr_index_00] 
tr_index_25 = [index - datetime.timedelta(minutes=25) for index in tr_index_00]
tr_index_20 = [index - datetime.timedelta(minutes=20) for index in tr_index_00]
tr_index_15 = [index - datetime.timedelta(minutes=15) for index in tr_index_00]
tr_index_10 = [index - datetime.timedelta(minutes=10) for index in tr_index_00]
tr_index_05 = [index - datetime.timedelta(minutes=5) for index in tr_index_00]

tr_index15  = [index + datetime.timedelta(minutes=15) for index in tr_index_00]
tr_index30  = [index + datetime.timedelta(minutes=30) for index in tr_index_00]
tr_index45  = [index + datetime.timedelta(minutes=45) for index in tr_index_00]
tr_index60  = [index + datetime.timedelta(minutes=60) for index in tr_index_00]
tr_index90  = [index + datetime.timedelta(minutes=90) for index in tr_index_00]
tr_index120  = [index + datetime.timedelta(minutes=120) for index in tr_index_00]
tr_index150  = [index + datetime.timedelta(minutes=150) for index in tr_index_00]
tr_index180  = [index + datetime.timedelta(minutes=180) for index in tr_index_00]

# %%
bands = ['c1','c3','c4','c5','c6','c7','c9','c11']
dfs = [df_c1,df_c3,df_c4,df_c5,df_c6,df_c7,df_c9,df_c11]
times = ['_60','_55','_50','_45','_40','_35','_30','_25','_20','_15','_10','_05','_00']
indexes = [tr_index_60,tr_index_55,tr_index_50,tr_index_45,tr_index_40,tr_index_35,tr_index_30,
           tr_index_25,tr_index_20,tr_index_15,tr_index_10,tr_index_15,tr_index_00]

inputs = {}

for band,df in zip(bands,dfs):
    for time,index in zip(times,indexes):
        inputs['train'+'_'+band+time] = df.loc[index].values.reshape(len(index),21,21)
#inputs

# %%
te_index_00 = [index for index in index_ if index in te_index]

te_index_60 = [index - datetime.timedelta(minutes=60) for index in te_index_00]
te_index_55 = [index - datetime.timedelta(minutes=55) for index in te_index_00]
te_index_50 = [index - datetime.timedelta(minutes=50) for index in te_index_00]
te_index_45 = [index - datetime.timedelta(minutes=45) for index in te_index_00]
te_index_40 = [index - datetime.timedelta(minutes=40) for index in te_index_00]
te_index_35 = [index - datetime.timedelta(minutes=35) for index in te_index_00]
te_index_30 = [index - datetime.timedelta(minutes=30) for index in te_index_00] 
te_index_25 = [index - datetime.timedelta(minutes=25) for index in te_index_00]
te_index_20 = [index - datetime.timedelta(minutes=20) for index in te_index_00]
te_index_15 = [index - datetime.timedelta(minutes=15) for index in te_index_00]
te_index_10 = [index - datetime.timedelta(minutes=10) for index in te_index_00]
te_index_05 = [index - datetime.timedelta(minutes=5) for index in te_index_00]

te_index15  = [index + datetime.timedelta(minutes=15) for index in te_index_00]
te_index30  = [index + datetime.timedelta(minutes=30) for index in te_index_00]
te_index45  = [index + datetime.timedelta(minutes=45) for index in te_index_00]
te_index60  = [index + datetime.timedelta(minutes=60) for index in te_index_00]
te_index90  = [index + datetime.timedelta(minutes=90) for index in te_index_00]
te_index120  = [index + datetime.timedelta(minutes=120) for index in te_index_00]
te_index150  = [index + datetime.timedelta(minutes=150) for index in te_index_00]
te_index180  = [index + datetime.timedelta(minutes=180) for index in te_index_00]

# %%
bands = ['c1','c3','c4','c5','c6','c7','c9','c11']
dfs = [df_c1,df_c3,df_c4,df_c5,df_c6,df_c7,df_c9,df_c11]
times = ['_60','_55','_50','_45','_40','_35','_30','_25','_20','_15','_10','_05','_00']
indexes = [te_index_60,te_index_55,te_index_50,te_index_45,te_index_40,te_index_35,te_index_30,
           te_index_25,te_index_20,te_index_15,te_index_10,te_index_05,te_index_00]

te_inputs = {}

for band,df in zip(bands,dfs):
    for time,index in zip(times,indexes):
        te_inputs['test'+'_'+band+time] = df.loc[index].values.reshape(len(index),21,21)
#te_inputs

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Attention, Dense, Layer, Input, Conv2D, MaxPool2D, concatenate, Flatten, Dropout, BatchNormalization
from tensorflow.keras.utils import plot_model
from tensorflow.keras import regularizers, callbacks
import tensorflow.keras.backend as K

# %%
class attention(Layer):
    
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)
        
    def build(self,input_shape):
        self.W = self.add_weight(name = 'attention_weight', shape = (input_shape[-1],1),
                                 initializer = 'random_normal', trainable = True)
        self.b = self.add_weight(name = 'attention_bias', shape = (input_shape[1],1),
                                 initializer = 'zeros', trainable = True)
        super(attention,self).build(input_shape)
        
    def call(self,x):
        e = K.tanh(K.dot(x,self.W)+self.b)
        e = K.squeeze(e,axis=-1)
        alpha = K.softmax(e)
        alpha = K.expand_dims(alpha,axis=-1)
        context = x*alpha
        context = K.sum(context,axis=1)
        return context

# %%
def input_one(hp,input_x):
    
    x = BatchNormalization()(input_x)
    
    return x

def input_eight(hp,input_1,input_3,input_4,input_5,input_6,input_7,input_9,input_11):
    
    x_1 = input_one(hp,input_1)
    x_3 = input_one(hp,input_3)
    x_4 = input_one(hp,input_4)
    x_5 = input_one(hp,input_5)
    x_6 = input_one(hp,input_6)
    x_7 = input_one(hp,input_7)
    x_9 = input_one(hp,input_9)
    x_11 = input_one(hp,input_11)
    
    x = concatenate([x_1,x_3,x_4,x_5,x_6,x_7,x_9,x_11])
    
    return x

# %%
def model_builder(hp):
    
    input_c1_60 = Input(shape=[21,21,1])
    input_c3_60 = Input(shape=[21,21,1])
    input_c4_60 = Input(shape=[21,21,1])
    input_c5_60 = Input(shape=[21,21,1])
    input_c6_60 = Input(shape=[21,21,1])
    input_c7_60 = Input(shape=[21,21,1])
    input_c9_60 = Input(shape=[21,21,1])
    input_c11_60 = Input(shape=[21,21,1])

    input_c1_55 = Input(shape=[21,21,1])
    input_c3_55 = Input(shape=[21,21,1])
    input_c4_55 = Input(shape=[21,21,1])
    input_c5_55 = Input(shape=[21,21,1])
    input_c6_55 = Input(shape=[21,21,1])
    input_c7_55 = Input(shape=[21,21,1])
    input_c9_55 = Input(shape=[21,21,1])
    input_c11_55 = Input(shape=[21,21,1])

    input_c1_50 = Input(shape=[21,21,1])
    input_c3_50 = Input(shape=[21,21,1])
    input_c4_50 = Input(shape=[21,21,1])
    input_c5_50 = Input(shape=[21,21,1])
    input_c6_50 = Input(shape=[21,21,1])
    input_c7_50 = Input(shape=[21,21,1])
    input_c9_50 = Input(shape=[21,21,1])
    input_c11_50 = Input(shape=[21,21,1])

    input_c1_45 = Input(shape=[21,21,1])
    input_c3_45 = Input(shape=[21,21,1])
    input_c4_45 = Input(shape=[21,21,1])
    input_c5_45 = Input(shape=[21,21,1])
    input_c6_45 = Input(shape=[21,21,1])
    input_c7_45 = Input(shape=[21,21,1])
    input_c9_45 = Input(shape=[21,21,1])
    input_c11_45 = Input(shape=[21,21,1])

    input_c1_40 = Input(shape=[21,21,1])
    input_c3_40 = Input(shape=[21,21,1])
    input_c4_40 = Input(shape=[21,21,1])
    input_c5_40 = Input(shape=[21,21,1])
    input_c6_40 = Input(shape=[21,21,1])
    input_c7_40 = Input(shape=[21,21,1])
    input_c9_40 = Input(shape=[21,21,1])
    input_c11_40 = Input(shape=[21,21,1])

    input_c1_35 = Input(shape=[21,21,1])
    input_c3_35 = Input(shape=[21,21,1])
    input_c4_35 = Input(shape=[21,21,1])
    input_c5_35 = Input(shape=[21,21,1])
    input_c6_35 = Input(shape=[21,21,1])
    input_c7_35 = Input(shape=[21,21,1])
    input_c9_35 = Input(shape=[21,21,1])
    input_c11_35 = Input(shape=[21,21,1])

    input_c1_30 = Input(shape=[21,21,1])
    input_c3_30 = Input(shape=[21,21,1])
    input_c4_30 = Input(shape=[21,21,1])
    input_c5_30 = Input(shape=[21,21,1])
    input_c6_30 = Input(shape=[21,21,1])
    input_c7_30 = Input(shape=[21,21,1])
    input_c9_30 = Input(shape=[21,21,1])
    input_c11_30 = Input(shape=[21,21,1])

    input_c1_25 = Input(shape=[21,21,1])
    input_c3_25 = Input(shape=[21,21,1])
    input_c4_25 = Input(shape=[21,21,1])
    input_c5_25 = Input(shape=[21,21,1])
    input_c6_25 = Input(shape=[21,21,1])
    input_c7_25 = Input(shape=[21,21,1])
    input_c9_25 = Input(shape=[21,21,1])
    input_c11_25 = Input(shape=[21,21,1])

    input_c1_20 = Input(shape=[21,21,1])
    input_c3_20 = Input(shape=[21,21,1])
    input_c4_20 = Input(shape=[21,21,1])
    input_c5_20 = Input(shape=[21,21,1])
    input_c6_20 = Input(shape=[21,21,1])
    input_c7_20 = Input(shape=[21,21,1])
    input_c9_20 = Input(shape=[21,21,1])
    input_c11_20 = Input(shape=[21,21,1])

    input_c1_15 = Input(shape=[21,21,1])
    input_c3_15 = Input(shape=[21,21,1])
    input_c4_15 = Input(shape=[21,21,1])
    input_c5_15 = Input(shape=[21,21,1])
    input_c6_15 = Input(shape=[21,21,1])
    input_c7_15 = Input(shape=[21,21,1])
    input_c9_15 = Input(shape=[21,21,1])
    input_c11_15 = Input(shape=[21,21,1])

    input_c1_10 = Input(shape=[21,21,1])
    input_c3_10 = Input(shape=[21,21,1])
    input_c4_10 = Input(shape=[21,21,1])
    input_c5_10 = Input(shape=[21,21,1])
    input_c6_10 = Input(shape=[21,21,1])
    input_c7_10 = Input(shape=[21,21,1])
    input_c9_10 = Input(shape=[21,21,1])
    input_c11_10 = Input(shape=[21,21,1])

    input_c1_05 = Input(shape=[21,21,1])
    input_c3_05 = Input(shape=[21,21,1])
    input_c4_05 = Input(shape=[21,21,1])
    input_c5_05 = Input(shape=[21,21,1])
    input_c6_05 = Input(shape=[21,21,1])
    input_c7_05 = Input(shape=[21,21,1])
    input_c9_05 = Input(shape=[21,21,1])
    input_c11_05 = Input(shape=[21,21,1])

    input_c1_00 = Input(shape=[21,21,1])
    input_c3_00 = Input(shape=[21,21,1])
    input_c4_00 = Input(shape=[21,21,1])
    input_c5_00 = Input(shape=[21,21,1])
    input_c6_00 = Input(shape=[21,21,1])
    input_c7_00 = Input(shape=[21,21,1])
    input_c9_00 = Input(shape=[21,21,1])
    input_c11_00 = Input(shape=[21,21,1])

    x_60 = input_eight(hp,input_c1_60,input_c3_60,input_c4_60,input_c5_60,input_c6_60,input_c7_60,input_c9_60,input_c11_60)
    x_55 = input_eight(hp,input_c1_55,input_c3_55,input_c4_55,input_c5_55,input_c6_55,input_c7_55,input_c9_55,input_c11_55)
    x_50 = input_eight(hp,input_c1_50,input_c3_50,input_c4_50,input_c5_50,input_c6_50,input_c7_50,input_c9_50,input_c11_50)
    x_45 = input_eight(hp,input_c1_45,input_c3_45,input_c4_45,input_c5_45,input_c6_45,input_c7_45,input_c9_45,input_c11_45)
    x_40 = input_eight(hp,input_c1_40,input_c3_40,input_c4_40,input_c5_40,input_c6_40,input_c7_40,input_c9_40,input_c11_40)
    x_35 = input_eight(hp,input_c1_35,input_c3_35,input_c4_35,input_c5_35,input_c6_35,input_c7_35,input_c9_35,input_c11_35)
    x_30 = input_eight(hp,input_c1_30,input_c3_30,input_c4_30,input_c5_30,input_c6_30,input_c7_30,input_c9_30,input_c11_30)
    x_25 = input_eight(hp,input_c1_25,input_c3_25,input_c4_25,input_c5_25,input_c6_25,input_c7_25,input_c9_25,input_c11_25)
    x_20 = input_eight(hp,input_c1_20,input_c3_20,input_c4_20,input_c5_20,input_c6_20,input_c7_20,input_c9_20,input_c11_20)
    x_15 = input_eight(hp,input_c1_15,input_c3_15,input_c4_15,input_c5_15,input_c6_15,input_c7_15,input_c9_15,input_c11_15)
    x_10 = input_eight(hp,input_c1_10,input_c3_10,input_c4_10,input_c5_10,input_c6_10,input_c7_10,input_c9_10,input_c11_10)
    x_05 = input_eight(hp,input_c1_05,input_c3_05,input_c4_05,input_c5_05,input_c6_05,input_c7_05,input_c9_05,input_c11_05)
    x_00 = input_eight(hp,input_c1_00,input_c3_00,input_c4_00,input_c5_00,input_c6_00,input_c7_00,input_c9_00,input_c11_00)

    x = concatenate([x_60,x_55,x_50,x_45,x_40,x_35,x_30,x_25,x_20,x_15,x_10,x_05,x_00])

    hp_layer_1 = hp.Int('layer_1', min_value=16, max_value=128, step=2)
    hp_layer_2 = hp.Int('layer_2', min_value=8, max_value=64, step=2)
    hp_layer_3 = hp.Int('layer_3', min_value=8, max_value=64, step=2)
    hp_layer_4 = hp.Int('layer_4', min_value=8, max_value=64, step=2)
    
    hp_activation_1 = hp.Choice('activation_1', values=['relu','gelu','selu','tanh'])
    hp_activation_2 = hp.Choice('activation_2', values=['relu','gelu','selu','tanh'])
    hp_activation_3 = hp.Choice('activation_3', values=['relu','gelu','selu','tanh'])
    hp_activation_4 = hp.Choice('activation_4', values=['relu','gelu','selu','linear'])
    
    x = Conv2D(filters=hp_layer_1, kernel_size = 3, activation = hp_activation_1)(x)
    x = BatchNormalization()(x)
    x = MaxPool2D((2,2))(x)
    x = BatchNormalization()(x)
    x = Conv2D(filters=hp_layer_2, kernel_size = 3, activation = hp_activation_2)(x)
    x = BatchNormalization()(x)
    # x = MaxPool2D((2,2))(x)
    # x = BatchNormalization()(x)
    x = attention()(x)
    x = BatchNormalization()(x)

    x = Flatten()(x)

    x = Dense(units=hp_layer_3, activation = hp_activation_3, kernel_regularizer = regularizers.l2(0.01))(x)

    x = Dense(units=hp_layer_4, activation = hp_activation_4)(x)

    output_15 = Dense(1, activation = 'relu')(x)

    output_30 = Dense(1, activation = 'relu')(x)

    output_45 = Dense(1, activation = 'relu')(x)

    output_60 = Dense(1, activation = 'relu')(x)
    
    output_90 = Dense(1, activation = 'relu')(x)

    output_120 = Dense(1, activation = 'relu')(x)

    output_150 = Dense(1, activation = 'relu')(x)

    output_180 = Dense(1, activation = 'relu')(x)

    model = Model(inputs = [input_c1_60,input_c3_60,input_c4_60,input_c5_60,input_c6_60,input_c7_60,input_c9_60,input_c11_60,
                            input_c1_55,input_c3_55,input_c4_55,input_c5_55,input_c6_55,input_c7_55,input_c9_55,input_c11_55,
                            input_c1_50,input_c3_50,input_c4_50,input_c5_50,input_c6_50,input_c7_50,input_c9_50,input_c11_50,
                            input_c1_45,input_c3_45,input_c4_45,input_c5_45,input_c6_45,input_c7_45,input_c9_45,input_c11_45,
                            input_c1_40,input_c3_40,input_c4_40,input_c5_40,input_c6_40,input_c7_40,input_c9_40,input_c11_40,
                            input_c1_35,input_c3_35,input_c4_35,input_c5_35,input_c6_35,input_c7_35,input_c9_35,input_c11_35,
                            input_c1_30,input_c3_30,input_c4_30,input_c5_30,input_c6_30,input_c7_30,input_c9_30,input_c11_30,
                            input_c1_25,input_c3_25,input_c4_25,input_c5_25,input_c6_25,input_c7_25,input_c9_25,input_c11_25,
                            input_c1_20,input_c3_20,input_c4_20,input_c5_20,input_c6_20,input_c7_20,input_c9_20,input_c11_20,
                            input_c1_15,input_c3_15,input_c4_15,input_c5_15,input_c6_15,input_c7_15,input_c9_15,input_c11_15,
                            input_c1_10,input_c3_10,input_c4_10,input_c5_10,input_c6_10,input_c7_10,input_c9_10,input_c11_10,
                            input_c1_05,input_c3_05,input_c4_05,input_c5_05,input_c6_05,input_c7_05,input_c9_05,input_c11_05,
                            input_c1_00,input_c3_00,input_c4_00,input_c5_00,input_c6_00,input_c7_00,input_c9_00,input_c11_00],
                  outputs = [output_15,output_30,output_45,output_60,output_90,output_120,output_150,output_180]
                 )


    hp_learning_rate = hp.Choice('learning_rate', values=[1e-5,1e-4,2e-4,5e-4,1e-3,2e-3,1e-2])
    
    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
             loss = 'huber',
             metrics = tf.keras.metrics.MeanAbsoluteError())

    return model

# %%
import keras_tuner as kt # to select the optimal parameters

tuner = kt.BayesianOptimization(model_builder,
                                objective=kt.Objective("val_loss",direction="min"),
                                max_trials=50,
                                seed=3,
                                directory='forecasting',
                                project_name='bon3h_sat')

# %%
early_stop = callbacks.EarlyStopping(monitor='val_loss',mode='min',patience=5)
callback_list = [early_stop]

# %%
train_output_15 = df_ghi.loc[tr_index15,'CSI'].values.reshape(len(tr_index15),1)
train_output_30 = df_ghi.loc[tr_index30,'CSI'].values.reshape(len(tr_index30),1)
train_output_45 = df_ghi.loc[tr_index45,'CSI'].values.reshape(len(tr_index45),1)
train_output_60 = df_ghi.loc[tr_index60,'CSI'].values.reshape(len(tr_index60),1)
train_output_90 = df_ghi.loc[tr_index90,'CSI'].values.reshape(len(tr_index90),1)
train_output_120 = df_ghi.loc[tr_index120,'CSI'].values.reshape(len(tr_index120),1)
train_output_150 = df_ghi.loc[tr_index150,'CSI'].values.reshape(len(tr_index150),1)
train_output_180 = df_ghi.loc[tr_index180,'CSI'].values.reshape(len(tr_index180),1)

test_output_15 = df_ghi.loc[te_index15,'CSI'].values.reshape(len(te_index15),1)
test_output_30 = df_ghi.loc[te_index30,'CSI'].values.reshape(len(te_index30),1)
test_output_45 = df_ghi.loc[te_index45,'CSI'].values.reshape(len(te_index45),1)
test_output_60 = df_ghi.loc[te_index60,'CSI'].values.reshape(len(te_index60),1)
test_output_90 = df_ghi.loc[te_index90,'CSI'].values.reshape(len(te_index90),1)
test_output_120 = df_ghi.loc[te_index120,'CSI'].values.reshape(len(te_index120),1)
test_output_150 = df_ghi.loc[te_index150,'CSI'].values.reshape(len(te_index150),1)
test_output_180 = df_ghi.loc[te_index180,'CSI'].values.reshape(len(te_index180),1)

# %%
tuner.search([inputs[key] for key in inputs.keys()],
             [train_output_15,train_output_30,train_output_45,train_output_60,
              train_output_90,train_output_120,train_output_150,train_output_180], 
             epochs=5, 
             validation_split=0.2, 
             shuffle = True,
             callbacks=callback_list)

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
model = tuner.hypermodel.build(best_hps)
history = model.fit([[inputs[key] for key in inputs.keys()]],
                    [train_output_15,train_output_30,train_output_45,train_output_60,
                     train_output_90,train_output_120,train_output_150,train_output_180],
                    epochs=200, validation_split=0.2, shuffle = True,
                    callbacks=callback_list)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 87s 709ms/step - loss: 5.0955 - dense_5_loss: 0.2411 - dense_6_loss: 0.1803 - dense_7_loss: 0.0587 - dense_8_loss: 0.3048 - dense_9_loss: 0.2302 - dense_10_loss: 0.0975 - dense_11_loss: 0.2933 - dense_12_loss: 0.2290 - dense_5_mean_absolute_error: 0.5927 - dense_6_mean_absolute_error: 0.5075 - dense_7_mean_absolute_error: 0.2734 - dense_8_mean_absolute_error: 0.7330 - dense_9_mean_absolute_error: 0.5928 - dense_10_mean_absolute_error: 0.3911 - dense_11_mean_absolute_error: 0.6909 - dense_12_mean_absolute_error: 0.6171 - val_loss: 4.8362 - val_dense_5_loss: 0.0656 - val_dense_6_loss: 0.0398 - val_dense_7_loss: 0.2221 - val_dense_8_loss: 0.2827 - val_dense_9_loss: 0.1687 - val_dense_10_loss: 0.2695 - val_dense_11_loss: 0.1413 - val_dense_12_loss: 0.2220 - val_dense_5_mean_absolute_error: 0.3221 - val_dense_6_mean_absolute_error: 0.2240 - val_dense_7_mean_absolute_error: 0.6557 - val_dense_8_mean_absolute_error: 0.7478 - val_dense_9_mean_absolute_error: 0.5677 - val_dense_10_mean_absolute_error: 0.7260 - val_dense_11_mean_absolute_error: 0.5111 - val_dense_12_mean_absolute_error: 0.6534
# Epoch 2/100
# 44/44 [==============================] - 23s 515ms/step - loss: 4.0315 - dense_5_loss: 0.0509 - dense_6_loss: 0.1431 - dense_7_loss: 0.0465 - dense_8_loss: 0.0885 - dense_9_loss: 0.0553 - dense_10_loss: 0.0502 - dense_11_loss: 0.0749 - dense_12_loss: 0.1357 - dense_5_mean_absolute_error: 0.2565 - dense_6_mean_absolute_error: 0.4781 - dense_7_mean_absolute_error: 0.2558 - dense_8_mean_absolute_error: 0.3815 - dense_9_mean_absolute_error: 0.2903 - dense_10_mean_absolute_error: 0.2649 - dense_11_mean_absolute_error: 0.3010 - dense_12_mean_absolute_error: 0.4087 - val_loss: 4.9323 - val_dense_5_loss: 0.1487 - val_dense_6_loss: 0.1062 - val_dense_7_loss: 0.2630 - val_dense_8_loss: 0.2471 - val_dense_9_loss: 0.2642 - val_dense_10_loss: 0.2061 - val_dense_11_loss: 0.1866 - val_dense_12_loss: 0.1660 - val_dense_5_mean_absolute_error: 0.5353 - val_dense_6_mean_absolute_error: 0.4490 - val_dense_7_mean_absolute_error: 0.7149 - val_dense_8_mean_absolute_error: 0.6990 - val_dense_9_mean_absolute_error: 0.7213 - val_dense_10_mean_absolute_error: 0.6345 - val_dense_11_mean_absolute_error: 0.6024 - val_dense_12_mean_absolute_error: 0.5642
# 44/44 [==============================] - 23s 520ms/step - loss: 3.2682 - dense_5_loss: 0.0230 - dense_6_loss: 0.0427 - dense_7_loss: 0.0142 - dense_8_loss: 0.0165 - dense_9_loss: 0.0234 - dense_10_loss: 0.0120 - dense_11_loss: 0.0128 - dense_12_loss: 0.0159 - dense_5_mean_absolute_error: 0.1814 - dense_6_mean_absolute_error: 0.2547 - dense_7_mean_absolute_error: 0.1301 - dense_8_mean_absolute_error: 0.1550 - dense_9_mean_absolute_error: 0.1907 - dense_10_mean_absolute_error: 0.1272 - dense_11_mean_absolute_error: 0.1271 - dense_12_mean_absolute_error: 0.1319 - val_loss: 3.6054 - val_dense_5_loss: 0.0502 - val_dense_6_loss: 0.0241 - val_dense_7_loss: 0.0578 - val_dense_8_loss: 0.0956 - val_dense_9_loss: 0.1052 - val_dense_10_loss: 0.0722 - val_dense_11_loss: 0.0816 - val_dense_12_loss: 0.0634 - val_dense_5_mean_absolute_error: 0.2971 - val_dense_6_mean_absolute_error: 0.1922 - val_dense_7_mean_absolute_error: 0.3189 - val_dense_8_mean_absolute_error: 0.4274 - val_dense_9_mean_absolute_error: 0.4464 - val_dense_10_mean_absolute_error: 0.3688 - val_dense_11_mean_absolute_error: 0.3916 - val_dense_12_mean_absolute_error: 0.3420
# Epoch 6/100
# 44/44 [==============================] - 23s 514ms/step - loss: 3.1274 - dense_5_loss: 0.0184 - dense_6_loss: 0.0287 - dense_7_loss: 0.0107 - dense_8_loss: 0.0119 - dense_9_loss: 0.0193 - dense_10_loss: 0.0104 - dense_11_loss: 0.0107 - dense_12_loss: 0.0130 - dense_5_mean_absolute_error: 0.1589 - dense_6_mean_absolute_error: 0.2046 - dense_7_mean_absolute_error: 0.1114 - dense_8_mean_absolute_error: 0.1280 - dense_9_mean_absolute_error: 0.1723 - dense_10_mean_absolute_error: 0.1176 - dense_11_mean_absolute_error: 0.1154 - dense_12_mean_absolute_error: 0.1186 - val_loss: 3.3396 - val_dense_5_loss: 0.0357 - val_dense_6_loss: 0.0165 - val_dense_7_loss: 0.0335 - val_dense_8_loss: 0.0674 - val_dense_9_loss: 0.0733 - val_dense_10_loss: 0.0506 - val_dense_11_loss: 0.0641 - val_dense_12_loss: 0.0479 - val_dense_5_mean_absolute_error: 0.2388 - val_dense_6_mean_absolute_error: 0.1377 - val_dense_7_mean_absolute_error: 0.2305 - val_dense_8_mean_absolute_error: 0.3538 - val_dense_9_mean_absolute_error: 0.3661 - val_dense_10_mean_absolute_error: 0.3040 - val_dense_11_mean_absolute_error: 0.3416 - val_dense_12_mean_absolute_error: 0.2951
# Epoch 7/100
# 44/44 [==============================] - 23s 515ms/step - loss: 2.9981 - dense_5_loss: 0.0155 - dense_6_loss: 0.0207 - dense_7_loss: 0.0087 - dense_8_loss: 0.0091 - dense_9_loss: 0.0157 - dense_10_loss: 0.0092 - dense_11_loss: 0.0093 - dense_12_loss: 0.0113 - dense_5_mean_absolute_error: 0.1457 - dense_6_mean_absolute_error: 0.1700 - dense_7_mean_absolute_error: 0.0969 - dense_8_mean_absolute_error: 0.1060 - dense_9_mean_absolute_error: 0.1524 - dense_10_mean_absolute_error: 0.1093 - dense_11_mean_absolute_error: 0.1056 
# Epoch 10/100
# 44/44 [==============================] - 23s 514ms/step - loss: 2.6348 - dense_5_loss: 0.0095 - dense_6_loss: 0.0091 - dense_7_loss: 0.0058 - dense_8_loss: 0.0055 - dense_9_loss: 0.0098 - dense_10_loss: 0.0070 - dense_11_loss: 0.0068 - dense_12_loss: 0.0089 - dense_5_mean_absolute_error: 0.1088 - dense_6_mean_absolute_error: 0.0992 - dense_7_mean_absolute_error: 0.0787 - dense_8_mean_absolute_error: 0.0745 - dense_9_mean_absolute_error: 0.1156 - dense_10_mean_absolute_error: 0.0923 - dense_11_mean_absolute_error: 0.0855 - dense_12_mean_absolute_error: 0.0957 - val_loss: 2.6331 - val_dense_5_loss: 0.0107 - val_dense_6_loss: 0.0080 - val_dense_7_loss: 0.0084 - val_dense_8_loss: 0.0157 - val_dense_9_loss: 0.0221 - val_dense_10_loss: 0.0162 - val_dense_11_loss: 0.0210 - val_dense_12_loss: 0.0146 - val_dense_5_mean_absolute_error: 0.1117 - val_dense_6_mean_absolute_error: 0.0946 - val_dense_7_mean_absolute_error: 0.0990 - val_dense_8_mean_absolute_error: 0.1600 - val_dense_9_mean_absolute_error: 0.1918 - val_dense_10_mean_absolute_error: 0.1608 - val_dense_11_mean_absolute_error: 0.1825 - val_dense_12_mean_absolute_error: 0.1426
# Epoch 11/100
# 44/44 [==============================] - 23s 518ms/step - loss: 2.5186 - dense_5_loss: 0.0081 - dense_6_loss: 0.0072 - dense_7_loss: 0.0053 - dense_8_loss: 0.0049 - dense_9_loss: 0.0084 - dense_10_loss: 0.0064 - dense_11_loss: 0.0066 - dense_12_loss: 0.0082 - dense_5_mean_absolute_error: 0.0966 - dense_6_mean_absolute_error: 0.0846 - dense_7_mean_absolute_error: 0.0740 - dense_8_mean_absolute_error: 0.0686 - dense_9_mean_absolute_error: 0.1062 - dense_10_mean_absolute_error: 0.0875 - dense_11_mean_absolute_error: 0.0832 - dense_12_mean_absolute_error: 0.0906 - val_loss: 2.4902 - val_dense_5_loss: 0.0079 - val_dense_6_loss: 0.0056 - val_dense_7_loss: 0.0053 - val_dense_8_loss: 0.0101 - val_dense_9_loss: 0.0149 - val_dense_10_loss: 0.0110 - val_dense_11_loss: 0.0157 - val_dense_12_loss: 0.0118 - val_dense_5_mean_absolute_error: 0.0857 - val_dense_6_mean_absolute_error: 0.0764 - val_dense_7_mean_absolute_error: 0.0733 - val_dense_8_mean_absolute_error: 0.1213 - val_dense_9_mean_absolute_error: 0.1506 - val_dense_10_mean_absolute_error: 0.1259 - val_dense_11_mean_absolute_error: 0.1528 - val_dense_12_mean_absolute_error: 0.1228
# Epoch 12/100
# 44/44 [==============================] - 23s 521ms/step - loss: 2.4058 - dense_5_loss: 0.0072 - dense_6_loss: 0.0064 - dense_7_loss: 0.0051 - dense_8_loss: 0.0047 - dense_9_loss: 0.0074 - dense_10_loss: 0.0061 - dense_11_loss: 0.0060 - dense_12_loss: 0.0077 - dense_5_mean_absolute_error: 0.0908 - dense_6_mean_absolute_error: 0.0779 - dense_7_mean_absolute_error: 0.0711 - dense_8_mean_absolute_error: 0.0663 - dense_9_mean_absolute_error: 0.0965 - dense_10_mean_absolute_error: 0.0835 - dense_11_mean_absolute_error: 0.0776 - dense_12_mean_absolute_error: 0.0886 - val_loss: 2.3631 - val_dense_5_loss: 0.0065 - val_dense_6_loss: 0.0047 - val_dense_7_loss: 0.0043 - val_dense_8_loss: 0.0068 - val_dense_9_loss: 0.0107 - val_dense_10_loss: 0.0082 - val_dense_11_loss: 0.0116 - val_dense_12_loss: 0.0100 - val_dense_5_mean_absolute_error: 0.0739 - val_dense_6_mean_absolute_error: 0.0691 - val_dense_7_mean_absolute_error: 0.0646 - val_dense_8_mean_absolute_error: 0.0940 - val_dense_9_mean_absolute_error: 0.1245 - val_dense_10_mean_absolute_error: 0.1046 - val_dense_11_mean_absolute_error: 0.1236 - val_dense_12_mean_absolute_error: 0.1056
# Epoch 13/100
# 44/44 [==============================] - 23s 514ms/step - loss: 2.2942 - dense_5_loss: 0.0060 - dense_6_loss: 0.0057 - dense_7_loss: 0.0046 - dense_8_loss: 0.0043 - dense_9_loss: 0.0065 - dense_10_loss: 0.0056 - dense_11_loss: 0.0058 - dense_12_loss: 0.0071 - dense_5_mean_absolute_error: 0.0807 - dense_6_mean_absolute_error: 0.0727 - dense_7_mean_absolute_error: 0.0674 - dense_8_mean_absolute_error: 0.0619 - dense_9_mean_absolute_error: 0.0898 - dense_10_mean_absolute_error: 0.0783 - dense_11_mean_absolute_error: 0.0754 - dense_12_mean_absolute_error: 0.0844 - val_loss: 2.2404 - val_dense_5_loss: 0.0056 - val_dense_6_loss: 0.0042 - val_dense_7_loss: 0.0038 - val_dense_8_loss: 0.0042 - val_dense_9_loss: 0.0077 - val_dense_10_loss: 0.0058 - val_dense_11_loss: 0.0074 - val_dense_12_loss: 0.0076 - val_dense_5_mean_absolute_error: 0.0691 - val_dense_6_mean_absolute_error: 0.0631 - val_dense_7_mean_absolute_error: 0.0583 - val_dense_8_mean_absolute_error: 0.0662 - val_dense_9_mean_absolute_error: 0.0998 - val_dense_10_mean_absolute_error: 0.0830 - val_dense_11_mean_absolute_error: 0.0887 - val_dense_12_mean_absolute_error: 0.0870
# Epoch 14/100
# 44/44 [==============================] - 23s 515ms/step - loss: 2.1870 - dense_5_loss: 0.0057 - dense_6_loss: 0.0053 - dense_7_loss: 0.0045 - dense_8_loss: 0.0044 - dense_9_loss: 0.0061 - dense_10_loss: 0.0053 - dense_11_loss: 0.0056 - dense_12_loss: 0.0070 - dense_5_mean_absolute_error: 0.0776 - dense_6_mean_absolute_error: 0.0692 - dense_7_mean_absolute_error: 0.0661 - dense_8_mean_absolute_error: 0.0619 - dense_9_mean_absolute_error: 0.0845 - dense_10_mean_absolute_error: 0.0751 - dense_11_mean_absolute_error: 0.0728 - dense_12_mean_absolute_error: 0.0842 - val_loss: 2.1316 - val_dense_5_loss: 0.0055 - val_dense_6_loss: 0.
# 44/44 [==============================] - 23s 521ms/step - loss: 1.8792 - dense_5_loss: 0.0045 - dense_6_loss: 0.0045 - dense_7_loss: 0.0040 - dense_8_loss: 0.0042 - dense_9_loss: 0.0051 - dense_10_loss: 0.0048 - dense_11_loss: 0.0051 - dense_12_loss: 0.0060 - dense_5_mean_absolute_error: 0.0659 - dense_6_mean_absolute_error: 0.0635 - dense_7_mean_absolute_error: 0.0623 - dense_8_mean_absolute_error: 0.0596 - dense_9_mean_absolute_error: 0.0739 - dense_10_mean_absolute_error: 0.0686 - dense_11_mean_absolute_error: 0.0684 - dense_12_mean_absolute_error: 0.0770 - val_loss: 1.8274 - val_dense_5_loss: 0.0054 - val_dense_6_loss: 0.0040 - val_dense_7_loss: 0.0039 - val_dense_8_loss: 0.0025 - val_dense_9_loss: 0.0038 - val_dense_10_loss: 0.0037 - val_dense_11_loss: 0.0055 - val_dense_12_loss: 0.0069 - val_dense_5_mean_absolute_error: 0.0686 - val_dense_6_mean_absolute_error: 0.0617 - val_dense_7_mean_absolute_error: 0.0616 - val_dense_8_mean_absolute_error: 0.0500 - val_dense_9_mean_absolute_error: 0.0579 - val_dense_10_mean_absolute_error: 0.0559 - val_dense_11_mean_absolute_error: 0.0704 - val_dense_12_mean_absolute_error: 0.0804
# Epoch 18/100
# 44/44 [==============================] - 22s 510ms/step - loss: 1.7830 - dense_5_loss: 0.0044 - dense_6_loss: 0.0043 - dense_7_loss: 0.0039 - dense_8_loss: 0.0042 - dense_9_loss: 0.0048 - dense_10_loss: 0.0047 - dense_11_loss: 0.0051 - dense_12_loss: 0.0061 - dense_5_mean_absolute_error: 0.0650 - dense_6_mean_absolute_error: 0.0633 - dense_7_mean_absolute_error: 0.0615 - dense_8_mean_absolute_error: 0.0598 - dense_9_mean_absolute_error: 0.0702 - dense_10_mean_absolute_error: 0.0668 - dense_11_mean_absolute_error: 0.0683 - dense_12_mean_absolute_error: 0.0780 - val_loss: 1.7320 - val_dense_5_loss: 0.0047 - val_dense_6_loss: 0.0036 - val_dense_7_loss: 0.0034 - val_dense_8_loss: 0.0026 - val_dense_9_loss: 0.0041 - val_dense_10_loss: 0.0038 - val_dense_11_loss: 0.0054 - val_dense_12_loss: 0.0068 - val_dense_5_mean_absolute_error: 0.0596 - val_dense_6_mean_absolute_error: 0.0542 - val_dense_7_mean_absolute_error: 0.0529 - val_dense_8_mean_absolute_error: 0.0484 - val_dense_9_mean_absolute_error: 0.0625 - val_dense_10_mean_absolute_error: 0.0591 - val_dense_11_mean_absolute_error: 0.0698 - val_dense_12_mean_absolute_error: 0.0807
# Epoch 19/100
# 44/44 [==============================] - 23s 515ms/step - loss: 1.6892 - dense_5_loss: 0.0042 - dense_6_loss: 0.0041 - dense_7_loss: 0.0037 - dense_8_loss: 0.0041 - dense_9_loss: 0.0046 - dense_10_loss: 0.0045 - dense_11_loss: 0.0049 - dense_12_loss: 0.0060 - dense_5_mean_absolute_error: 0.0624 - dense_6_mean_absolute_error: 0.0602 - dense_7_mean_absolute_error: 0.0583 - dense_8_mean_absolute_error: 0.0585 - dense_9_mean_absolute_error: 0.0674 - dense_10_mean_absolute_error: 0.0649 - dense_11_mean_absolute_error: 0.0673 - dense_12_mean_absolute_error: 0.0767 - val_loss: 1.6419 - val_dense_5_loss: 0.0050 - val_dense_6_loss: 0.0039 - val_dense_7_loss: 0.0040 - val_dense_8_loss: 0.0026 - val_dense_9_loss: 0.0038 - val_dense_10_loss: 0.0035 - val_dense_11_loss: 0.0056 - val_dense_12_loss: 0.0066 - val_dense_5_mean_absolute_error: 0.0645 - val_dense_6_mean_absolute_error: 0.0596 - val_dense_7_mean_absolute_error: 0.0658 - val_dense_8_mean_absolute_error: 0.0490 - val_dense_9_mean_absolute_error: 0.0571 - val_dense_10_mean_absolute_error: 0.0525 - val_dense_11_mean_absolute_error: 0.0697 - val_dense_12_mean_absolute_error: 0.0761
# Epoch 20/100
# 44/44 [==============================] - 22s 511ms/step - loss: 1.5987 - dense_5_loss: 0.0038 - dense_6_loss: 0.0040 - dense_7_loss: 0.0035 - dense_8_loss: 0.0040 - dense_9_loss: 0.0044 - dense_10_loss: 0.0045 - dense_11_loss: 0.0050 - dense_12_loss: 0.0057 - dense_5_mean_absolute_error: 0.0598 - dense_6_mean_absolute_error: 0.0589 - dense_7_mean_absolute_error: 0.0574 - dense_8_mean_absolute_error: 0.0576 - dense_9_mean_absolute_error: 0.0655 - dense_10_mean_absolute_error: 0.0630 - dense_11_mean_absolute_error: 0.0666 - dense_12_mean_absolute_error: 0.0733 - val_loss: 1.5549 - val_dense_5_loss: 0.0049 - val_dense_6_loss: 0.0038 - val_dense_7_loss: 0.0036 - val_dense_8_loss: 0.0029 - val_dense_9_loss: 0.0044 - val_dense_10_loss: 0.0038 - val_dense_11_loss: 0.0056 - val_dense_12_loss: 0.0070 - val_dense_5_mean_absolute_error: 0.0614 - val_dense_6_mean_absolute_error: 0.0568 - val_dense_7_mean_absolute_error: 0.0540 - val_dense_8_mean_absolute_error: 0.0513 - val_dense_9_mean_absolute_error: 0.0640 - val_dense_10_mean_absolute_error: 0.0587 - val_dense_11_mean_absolute_error: 0.0734 - val_dense_12_mean_absolute_error: 0.0805
# Epoch 21/100
# 44/44 [==============================] - 22s 512ms/step - loss: 1.5128 - dense_5_loss: 0.0042 - dense_6_loss: 0.0040 - dense_7_loss: 0.0037 - dense_8_loss: 0.0039 - dense_9_loss: 0.0043 - dense_10_loss: 0.0044 - dense_11_loss: 0.0049 - dense_12_loss: 0.0058 - dense_5_mean_absolute_error: 0.0612 - dense_6_mean_absolute_error: 0.0597 - dense_7_mean_absolute_error: 0.0585 - dense_8_mean_absolute_error: 0.0578 - dense_9_mean_absolute_error: 0.0651 - dense_10_mean_absolute_error: 0.0635 - dense_11_mean_absolute_error: 0.0662 - dense_12_mean_absolute_error: 0.0748 - val_loss: 1.4697 - val_dense_5_loss: 0.0055 - val_dense_6_loss: 0.0039 - val_dense_7_loss: 0.0036 - val_dense_8_loss: 0.0028 - val_dense_9_loss: 0.0038 - val_dense_10_loss: 0.0036 - val_dense_11_loss: 0.0052 - val_dense_12_loss: 0.0068 - val_dense_5_mean_absolute_error: 0.0658 - val_dense_6_mean_absolute_error: 0.0560 - val_dense_7_mean_absolute_error: 0.0562 - val_dense_8_mean_absolute_error: 0.0516 - val_dense_9_mean_absolute_error: 0.0553 - val_dense_10_mean_absolute_error: 0.0531 - val_dense_11_mean_absolute_error: 0.0683 - val_dense_12_mean_absolute_error: 0.0783
# Epoch 22/100
# 44/44 [==============================] - 23s 517ms/step - loss: 1.4295 - dense_5_loss: 0.0038 - dense_6_loss: 0.0041 - dense_7_loss: 0.0036 - dense_8_loss: 0.0039 - dense_9_loss: 0.0043 - dense_10_loss: 0.0044 - dense_11_loss: 0.0051 - dense_12_loss: 0.0056 - dense_5_mean_absolute_error: 0.0584 - dense_6_mean_absolute_error: 0.0596 - dense_7_mean_absolute_error: 0.0568 - dense_8_mean_absolute_error: 0.0574 - dense_9_mean_absolute_error: 0.0630 - dense_10_mean_absolute_error: 0.0623 - dense_11_mean_absolute_error: 0.0664 - dense_12_mean_absolute_error: 0.0735 - val_loss: 1.3865 - val_dense_5_loss: 0.0049 - val_dense_6_loss: 0.0034 - val_dense_7_loss: 0.0030 - val_dense_8_loss: 0.0026 - val_dense_9_loss: 0.0036 - val_dense_10_loss: 0.0035 - val_dense_11_loss: 0.0053 - val_dense_12_loss: 0.0068 - val_dense_5_mean_absolute_error: 0.0622 - val_dense_6_mean_absolute_error: 0.0521 - val_dense_7_mean_absolute_error: 0.0514 - val_dense_8_mean_absolute_error: 0.0491 - val_dense_9_mean_absolute_error: 0.0543 - val_dense_10_mean_absolute_error: 0.0525 - val_dense_11_mean_absolute_error: 0.0673 - val_dense_12_mean_absolute_error: 0.0793
# Epoch 23/100
# 44/44 [==============================] - 23s 520ms/step - loss: 1.3485 - dense_5_loss: 0.0038 - dense_6_loss: 0.0039 - dense_7_loss: 0.0035 - dense_8_loss: 0.0037 - dense_9_loss: 0.0040 - dense_10_loss: 0.0042 - dense_11_loss: 0.0048 - dense_12_loss: 0.0056 - dense_5_mean_absolute_error: 0.0573 - dense_6_mean_absolute_error: 0.0578 - dense_7_mean_absolute_error: 0.0557 - dense_8_mean_absolute_error: 0.0548 - dense_9_mean_absolute_error: 0.0597 - dense_10_mean_absolute_error: 0.0599 - dense_11_mean_absolute_error: 0.0639 - dense_12_mean_absolute_error: 0.0732 - val_loss: 1.3087 - val_dense_5_loss: 0.0045 - val_dense_6_loss: 0.0033 - val_dense_7_loss: 0.0033 - val_dense_8_loss: 0.0026 - val_dense_9_loss: 0.0037 - val_dense_10_loss: 0.0036 - val_dense_11_loss: 0.0054 - val_dense_12_loss: 0.0068 - val_dense_5_mean_absolute_error: 0.0597 - val_dense_6_mean_absolute_error: 0.0520 - val_dense_7_mean_absolute_error: 0.0552 - val_dense_8_mean_absolute_error: 0.0489 - val_dense_9_mean_absolute_error: 0.0580 - val_dense_10_mean_absolute_error: 0.0556 - val_dense_11_mean_absolute_error: 0.0707 - val_dense_12_mean_absolute_error: 0.0807
# Epoch 24/100
# 44/44 [==============================] - 23s 518ms/step - loss: 1.2724 - dense_5_loss: 0.0038 - dense_6_loss: 0.0039 - dense_7_loss: 0.0035 - dense_8_loss: 0.0039 - dense_9_loss: 0.0040 - dense_10_loss: 0.0043 - dense_11_loss: 0.0046 - dense_12_loss: 0.0055 - dense_5_mean_absolute_error: 0.0573 - dense_6_mean_absolute_error: 0.0582 - dense_7_mean_absolute_error: 0.0560 - dense_8_mean_absolute_error: 0.0569 - dense_9_mean_absolute_error: 0.0602 - dense_10_mean_absolute_error: 0.0609 - dense_11_mean_absolute_error: 0.0638 - dense_12_mean_absolute_error: 0.0722 - val_loss: 1.2326 - val_dense_5_loss: 0.0042 - val_dense_6_loss: 0.
# 44/44 [==============================] - 23s 514ms/step - loss: 1.0617 - dense_5_loss: 0.0036 - dense_6_loss: 0.0037 - dense_7_loss: 0.0032 - dense_8_loss: 0.0037 - dense_9_loss: 0.0039 - dense_10_loss: 0.0041 - dense_11_loss: 0.0045 - dense_12_loss: 0.0051 - dense_5_mean_absolute_error: 0.0554 - dense_6_mean_absolute_error: 0.0561 - dense_7_mean_absolute_error: 0.0528 - dense_8_mean_absolute_error: 0.0547 - dense_9_mean_absolute_error: 0.0578 - dense_10_mean_absolute_error: 0.0584 - dense_11_mean_absolute_error: 0.0622 - dense_12_mean_absolute_error: 0.0691 - val_loss: 1.0266 - val_dense_5_loss: 0.0043 - val_dense_6_loss: 0.0031 - val_dense_7_loss: 0.0027 - val_dense_8_loss: 0.0023 - val_dense_9_loss: 0.0034 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0046 - val_dense_12_loss: 0.0059 - val_dense_5_mean_absolute_error: 0.0547 - val_dense_6_mean_absolute_error: 0.0489 - val_dense_7_mean_absolute_error: 0.0455 - val_dense_8_mean_absolute_error: 0.0440 - val_dense_9_mean_absolute_error: 0.0527 - val_dense_10_mean_absolute_error: 0.0497 - val_dense_11_mean_absolute_error: 0.0607 - val_dense_12_mean_absolute_error: 0.0720
# Epoch 28/100
# 44/44 [==============================] - 23s 516ms/step - loss: 0.9988 - dense_5_loss: 0.0035 - dense_6_loss: 0.0038 - dense_7_loss: 0.0032 - dense_8_loss: 0.0038 - dense_9_loss: 0.0039 - dense_10_loss: 0.0042 - dense_11_loss: 0.0047 - dense_12_loss: 0.0051 - dense_5_mean_absolute_error: 0.0561 - dense_6_mean_absolute_error: 0.0570 - dense_7_mean_absolute_error: 0.0534 - dense_8_mean_absolute_error: 0.0555 - dense_9_mean_absolute_error: 0.0583 - dense_10_mean_absolute_error: 0.0590 - dense_11_mean_absolute_error: 0.0633 - dense_12_mean_absolute_error: 0.0686 - val_loss: 0.9644 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 0.0030 - val_dense_7_loss: 0.0025 - val_dense_8_loss: 0.0022 - val_dense_9_loss: 0.0033 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0046 - val_dense_12_loss: 0.0061 - val_dense_5_mean_absolute_error: 0.0541 - val_dense_6_mean_absolute_error: 0.0500 - val_dense_7_mean_absolute_error: 0.0433 - val_dense_8_mean_absolute_error: 0.0438 - val_dense_9_mean_absolute_error: 0.0530 - val_dense_10_mean_absolute_error: 0.0513 - val_dense_11_mean_absolute_error: 0.0620 - val_dense_12_mean_absolute_error: 0.0743
# Epoch 29/100
# 44/44 [==============================] - 23s 520ms/step - loss: 0.9380 - dense_5_loss: 0.0036 - dense_6_loss: 0.0037 - dense_7_loss: 0.0030 - dense_8_loss: 0.0037 - dense_9_loss: 0.0037 - dense_10_loss: 0.0041 - dense_11_loss: 0.0046 - dense_12_loss: 0.0050 - dense_5_mean_absolute_error: 0.0551 - dense_6_mean_absolute_error: 0.0564 - dense_7_mean_absolute_error: 0.0512 - dense_8_mean_absolute_error: 0.0545 - dense_9_mean_absolute_error: 0.0564 - dense_10_mean_absolute_error: 0.0582 - dense_11_mean_absolute_error: 0.0629 - dense_12_mean_absolute_error: 0.0685 - val_loss: 0.9063 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 0.0029 - val_dense_7_loss: 0.0026 - val_dense_8_loss: 0.0022 - val_dense_9_loss: 0.0034 - val_dense_10_loss: 0.0034 - val_dense_11_loss: 0.0047 - val_dense_12_loss: 0.0063 - val_dense_5_mean_absolute_error: 0.0506 - val_dense_6_mean_absolute_error: 0.0476 - val_dense_7_mean_absolute_error: 0.0473 - val_dense_8_mean_absolute_error: 0.0436 - val_dense_9_mean_absolute_error: 0.0539 - val_dense_10_mean_absolute_error: 0.0533 - val_dense_11_mean_absolute_error: 0.0630 - val_dense_12_mean_absolute_error: 0.0727
# Epoch 30/100
# 44/44 [==============================] - 23s 513ms/step - loss: 0.8811 - dense_5_loss: 0.0035 - dense_6_loss: 0.0037 - dense_7_loss: 0.0031 - dense_8_loss: 0.0037 - dense_9_loss: 0.0038 - dense_10_loss: 0.0042 - dense_11_loss: 0.0046 - dense_12_loss: 0.0050 - dense_5_mean_absolute_error: 0.0553 - dense_6_mean_absolute_error: 0.0560 - dense_7_mean_absolute_error: 0.0522 - dense_8_mean_absolute_error: 0.0545 - dense_9_mean_absolute_error: 0.0570 - dense_10_mean_absolute_error: 0.0582 - dense_11_mean_absolute_error: 0.0628 - dense_12_mean_absolute_error: 0.0675 - val_loss: 0.8503 - val_dense_5_loss: 0.0040 - val_dense_6_loss: 0.0032 - val_dense_7_loss: 0.0024 - val_dense_8_loss: 0.0022 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0034 - val_dense_11_loss: 0.0044 - val_dense_12_loss: 0.0063 - val_dense_5_mean_absolute_error: 0.0561 - val_dense_6_mean_absolute_error: 0.0537 - val_dense_7_mean_absolute_error: 0.0430 - val_dense_8_mean_absolute_error: 0.0463 - val_dense_9_mean_absolute_error: 0.0478 - val_dense_10_mean_absolute_error: 0.0539 - val_dense_11_mean_absolute_error: 0.0619 - val_dense_12_mean_absolute_error: 0.0804
# Epoch 31/100
# 44/44 [==============================] - 23s 515ms/step - loss: 0.8267 - dense_5_loss: 0.0034 - dense_6_loss: 0.0036 - dense_7_loss: 0.0031 - dense_8_loss: 0.0037 - dense_9_loss: 0.0037 - dense_10_loss: 0.0041 - dense_11_loss: 0.0045 - dense_12_loss: 0.0049 - dense_5_mean_absolute_error: 0.0545 - dense_6_mean_absolute_error: 0.0552 - dense_7_mean_absolute_error: 0.0513 - dense_8_mean_absolute_error: 0.0544 - dense_9_mean_absolute_error: 0.0559 - dense_10_mean_absolute_error: 0.0575 - dense_11_mean_absolute_error: 0.0614 - dense_12_mean_absolute_error: 0.0671 - val_loss: 0.7975 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0028 - val_dense_8_loss: 0.0021 - val_dense_9_loss: 0.0034 - val_dense_10_loss: 0.0034 - val_dense_11_loss: 0.0045 - val_dense_12_loss: 0.0058 - val_dense_5_mean_absolute_error: 0.0519 - val_dense_6_mean_absolute_error: 0.0439 - val_dense_7_mean_absolute_error: 0.0532 - val_dense_8_mean_absolute_error: 0.0434 - val_dense_9_mean_absolute_error: 0.0521 - val_dense_10_mean_absolute_error: 0.0503 - val_dense_11_mean_absolute_error: 0.0594 - val_dense_12_mean_absolute_error: 0.0705
# Epoch 32/100
# 44/44 [==============================] - 23s 514ms/step - loss: 0.7749 - dense_5_loss: 0.0034 - dense_6_loss: 0.0036 - dense_7_loss: 0.0030 - dense_8_loss: 0.0036 - dense_9_loss: 0.0036 - dense_10_loss: 0.0040 - dense_11_loss: 0.0045 - dense_12_loss: 0.0048 - dense_5_mean_absolute_error: 0.0536 - dense_6_mean_absolute_error: 0.0544 - dense_7_mean_absolute_error: 0.0500 - dense_8_mean_absolute_error: 0.0531 - dense_9_mean_absolute_error: 0.0546 - dense_10_mean_absolute_error: 0.0565 - dense_11_mean_absolute_error: 0.0614 - dense_12_mean_absolute_error: 0.0660 - val_loss: 0.7471 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0025 - val_dense_8_loss: 0.0021 - val_dense_9_loss: 0.0032 - val_dense_10_loss: 0.0032 - val_dense_11_loss: 0.0045 - val_dense_12_loss: 0.0060 - val_dense_5_mean_absolute_error: 0.0485 - val_dense_6_mean_absolute_error: 0.0423 - val_dense_7_mean_absolute_error: 0.0453 - val_dense_8_mean_absolute_error: 0.0410 - val_dense_9_mean_absolute_error: 0.0489 - val_dense_10_mean_absolute_error: 0.0488 - val_dense_11_mean_absolute_error: 0.0591 - val_dense_12_mean_absolute_error: 0.0692
# Epoch 33/100
# 44/44 [==============================] - 23s 517ms/step - loss: 0.7264 - dense_5_loss: 0.0034 - dense_6_loss: 0.0035 - dense_7_loss: 0.0030 - dense_8_loss: 0.0035 - dense_9_loss: 0.0036 - dense_10_loss: 0.0039 - dense_11_loss: 0.0044 - dense_12_loss: 0.0048 - dense_5_mean_absolute_error: 0.0529 - dense_6_mean_absolute_error: 0.0527 - dense_7_mean_absolute_error: 0.0492 - dense_8_mean_absolute_error: 0.0518 - dense_9_mean_absolute_error: 0.0537 - dense_10_mean_absolute_error: 0.0548 - dense_11_mean_absolute_error: 0.0599 - dense_12_mean_absolute_error: 0.0659 - val_loss: 0.6995 - val_dense_5_loss: 0.0037 - val_dense_6_loss: 0.0028 - val_dense_7_loss: 0.0023 - val_dense_8_loss: 0.0020 - val_dense_9_loss: 0.0031 - val_dense_10_loss: 0.0032 - val_dense_11_loss: 0.0042 - val_dense_12_loss: 0.0058 - val_dense_5_mean_absolute_error: 0.0501 - val_dense_6_mean_absolute_error: 0.0445 - val_dense_7_mean_absolute_error: 0.0409 - val_dense_8_mean_absolute_error: 0.0412 - val_dense_9_mean_absolute_error: 0.0456 - val_dense_10_mean_absolute_error: 0.0476 - val_dense_11_mean_absolute_error: 0.0573 - val_dense_12_mean_absolute_error: 0.0701
# Epoch 34/100
# 44/44 [==============================] - 23s 515ms/step - loss: 0.6811 - dense_5_loss: 0.0034 - dense_6_loss: 0.0035 - dense_7_loss: 0.0030 - dense_8_loss: 0.0036 - dense_9_loss: 0.0037 - dense_10_loss: 0.0041 - dense_11_loss: 0.0045 - dense_12_loss: 0.0048 - dense_5_mean_absolute_error: 0.0533 - dense_6_mean_absolute_error: 0.0539 - dense_7_mean_absolute_error: 0.0499 - dense_8_mean_absolute_error: 0.0533 - dense_9_mean_absolute_error: 0.0550 - dense_10_mean_absolute_error: 0.0570 - dense_11_mean_absolute_error: 0.0619 - dense_12_mean_absolute_error: 0.0662 - val_loss: 0.6549 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 0.0029 - val_dense_7_loss: 0.0022 - val_dense_8_loss: 0.0020 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0041 - val_dense_12_loss: 0.0056 - val_dense_5_mean_absolute_error: 0.0496 - val_dense_6_mean_absolute_error: 0.0460 - val_dense_7_mean_absolute_error: 0.0392 - val_dense_8_mean_absolute_error: 0.0408 - val_dense_9_mean_absolute_error: 0.0455 - val_dense_10_mean_absolute_error: 0.0485 - val_dense_11_mean_absolute_error: 0.0569 - val_dense_12_mean_absolute_error: 0.0700
# Epoch 35/100
# 44/44 [==============================] - 23s 517ms/step - loss: 0.6383 - dense_5_loss: 0.0034 - dense_6_loss: 0.0034 - dense_7_loss: 0.0030 - dense_8_loss: 0.0037 - dense_9_loss: 0.0036 - dense_10_loss: 0.0040 - dense_11_loss: 0.0046 - dense_12_loss: 0.0049 - dense_5_mean_absolute_error: 0.0542 - dense_6_mean_absolute_error: 0.0540 - dense_7_mean_absolute_error: 0.0504 - dense_8_mean_absolute_error: 0.0543 - dense_9_mean_absolute_error: 0.0547 - dense_10_mean_absolute_error: 0.0569 - dense_11_mean_absolute_error: 0.0620 - dense_12_mean_absolute_error: 0.0667 - val_loss: 0.6137 - val_dense_5_loss: 0.0036 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0023 - val_dense_8_loss: 0.0020 - val_dense_9_loss: 0.0031 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0044 - val_dense_12_loss: 0.0059 - val_dense_5_mean_absolute_error: 0.0487 - val_dense_6_mean_absolute_error: 0.0419 - val_dense_7_mean_absolute_error: 0.0430 - val_dense_8_mean_absolute_error: 0.0404 - val_dense_9_mean_absolute_error: 0.0469 - val_dense_10_mean_absolute_error: 0.0484 - val_dense_11_mean_absolute_error: 0.0581 - val_dense_12_mean_absolute_error: 0.0688
# Epoch 36/100
# 44/44 [==============================] - 23s 518ms/step - loss: 0.5970 - dense_5_loss: 0.0033 - dense_6_loss: 0.0035 - dense_7_loss: 0.0029 - dense_8_loss: 0.0036 - dense_9_loss: 0.0035 - dense_10_loss: 0.0039 - dense_11_loss: 0.0045 - dense_12_loss: 0.0047 - dense_5_mean_absolute_error: 0.0519 - dense_6_mean_absolute_error: 0.0525 - dense_7_mean_absolute_error: 0.0483 - dense_8_mean_absolute_error: 0.0522 - dense_9_mean_absolute_error: 0.0529 - dense_10_mean_absolute_error: 0.0553 - dense_11_mean_absolute_error: 0.0611 - dense_12_mean_absolute_error: 0.0650 - val_loss: 0.5749 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0023 - val_dense_8_loss: 0.0020 - val_dense_9_loss: 0.0033 - val_dense_10_loss: 0.0034 - val_dense_11_loss: 0.0045 - val_dense_12_loss: 0.0059 - val_dense_5_mean_absolute_error: 0.0513 - val_dense_6_mean_absolute_error: 0.0440 - val_dense_7_mean_absolute_error: 0.0443 - val_dense_8_mean_absolute_error: 0.0419 - val_dense_9_mean_absolute_error: 0.0509 - val_dense_10_mean_absolute_error: 0.0505 - val_dense_11_mean_absolute_error: 0.0611 - val_dense_12_mean_absolute_error: 0.0697
# Epoch 37/100
# 44/44 [==============================] - 23s 517ms/step - loss: 0.5589 - dense_5_loss: 0.0033 - dense_6_loss: 0.0034 - dense_7_loss: 0.0028 - dense_8_loss: 0.0036 - dense_9_loss: 0.0036 - dense_10_loss: 0.0039 - dense_11_loss: 0.0045 - dense_12_loss: 0.0046 - dense_5_mean_absolute_error: 0.0518 - dense_6_mean_absolute_error: 0.0525 - dense_7_mean_absolute_error: 0.0480 - dense_8_mean_absolute_error: 0.0521 - dense_9_mean_absolute_error: 0.0534 - dense_10_mean_absolute_error: 0.0553 - dense_11_mean_absolute_error: 0.0608 - dense_12_mean_absolute_error: 0.0644 - val_loss: 0.5389 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0026 - val_dense_8_loss: 0.0021 - val_dense_9_loss: 0.0034 - val_dense_10_loss: 0.0035 - val_dense_11_loss: 0.0046 - val_dense_12_loss: 0.0061 - val_dense_5_mean_absolute_error: 0.0503 - val_dense_6_mean_absolute_error: 0.0445 - val_dense_7_mean_absolute_error: 0.0484 - val_dense_8_mean_absolute_error: 0.0429 - val_dense_9_mean_absolute_error: 0.0524 - val_dense_10_mean_absolute_error: 0.0540 - val_dense_11_mean_absolute_error: 0.0632 - val_dense_12_mean_absolute_error: 0.0721
# Epoch 38/100
# 44/44 [==============================] - 23s 514ms/step - loss: 0.5239 - dense_5_loss: 0.0035 - dense_6_loss: 0.0035 - dense_7_loss: 0.0030 - dense_8_loss: 0.0036 - dense_9_loss: 0.0036 - dense_10_loss: 0.0041 - dense_11_loss: 0.0046 - dense_12_loss: 0.0047 - dense_5_mean_absolute_error: 0.0546 - dense_6_mean_absolute_error: 0.0545 - dense_7_mean_absolute_error: 0.0507 - dense_8_mean_absolute_error: 0.0535 - dense_9_mean_absolute_error: 0.0548 - dense_10_mean_absolute_error: 0.0574 - dense_11_mean_absolute_error: 0.0623 - dense_12_mean_absolute_error: 0.0656 - val_loss: 0.5022 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0023 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0031 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0042 - val_dense_12_loss: 0.0056 - val_dense_5_mean_absolute_error: 0.0455 - val_dense_6_mean_absolute_error: 0.0423 - val_dense_7_mean_absolute_error: 0.0441 - val_dense_8_mean_absolute_error: 0.0378 - val_dense_9_mean_absolute_error: 0.0464 - val_dense_10_mean_absolute_error: 0.0485 - val_dense_11_mean_absolute_error: 0.0568 - val_dense_12_mean_absolute_error: 0.0679
# Epoch 39/100
# 44/44 [==============================] - 23s 523ms/step - loss: 0.4906 - dense_5_loss: 0.0034 - dense_6_loss: 0.0035 - dense_7_loss: 0.0029 - dense_8_loss: 0.0036 - dense_9_loss: 0.0038 - dense_10_loss: 0.0040 - dense_11_loss: 0.0046 - dense_12_loss: 0.0048 - dense_5_mean_absolute_error: 0.0544 - dense_6_mean_absolute_error: 0.0542 - dense_7_mean_absolute_error: 0.0504 - dense_8_mean_absolute_error: 0.0545 - dense_9_mean_absolute_error: 0.0560 - dense_10_mean_absolute_error: 0.0572 - dense_11_mean_absolute_error: 0.0620 - dense_12_mean_absolute_error: 0.0657 - val_loss: 0.4705 - val_dense_5_loss: 0.0035 - val_dense_6_loss: 0.0028 - val_dense_7_loss: 0.0025 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0031 - val_dense_10_loss: 0.0034 - val_dense_11_loss: 0.0042 - val_dense_12_loss: 0.0055 - val_dense_5_mean_absolute_error: 0.0472 - val_dense_6_mean_absolute_error: 0.0441 - val_dense_7_mean_absolute_error: 0.0476 - val_dense_8_mean_absolute_error: 0.0393 - val_dense_9_mean_absolute_error: 0.0476 - val_dense_10_mean_absolute_error: 0.0500 - val_dense_11_mean_absolute_error: 0.0575 - val_dense_12_mean_absolute_error: 0.0666
# Epoch 40/100
# 44/44 [==============================] - 23s 513ms/step - loss: 0.4585 - dense_5_loss: 0.0033 - dense_6_loss: 0.0033 - dense_7_loss: 0.0030 - dense_8_loss: 0.0036 - dense_9_loss: 0.0035 - dense_10_loss: 0.0039 - dense_11_loss: 0.0045 - dense_12_loss: 0.0048 - dense_5_mean_absolute_error: 0.0520 - dense_6_mean_absolute_error: 0.0507 - dense_7_mean_absolute_error: 0.0485 - dense_8_mean_absolute_error: 0.0519 - dense_9_mean_absolute_error: 0.0527 - dense_10_mean_absolute_error: 0.0552 - dense_11_mean_absolute_error: 0.0611 - dense_12_mean_absolute_error: 0.0654 - val_loss: 0.4395 - val_dense_5_loss: 0.0034 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0021 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0032 - val_dense_11_loss: 0.0041 - val_dense_12_loss: 0.0058 - val_dense_5_mean_absolute_error: 0.0482 - val_dense_6_mean_absolute_error: 0.0426 - val_dense_7_mean_absolute_error: 0.0377 - val_dense_8_mean_absolute_error: 0.0401 - val_dense_9_mean_absolute_error: 0.0440 - val_dense_10_mean_absolute_error: 0.0473 - val_dense_11_mean_absolute_error: 0.0571 - val_dense_12_mean_absolute_error: 0.0688
# Epoch 41/100
# 44/44 [==============================] - 23s 524ms/step - loss: 0.4297 - dense_5_loss: 0.0034 - dense_6_loss: 0.0033 - dense_7_loss: 0.0030 - dense_8_loss: 0.0036 - dense_9_loss: 0.0036 - dense_10_loss: 0.0040 - dense_11_loss: 0.0046 - dense_12_loss: 0.0048 - dense_5_mean_absolute_error: 0.0544 - dense_6_mean_absolute_error: 0.0532 - dense_7_mean_absolute_error: 0.0502 - dense_8_mean_absolute_error: 0.0542 - dense_9_mean_absolute_error: 0.0548 - dense_10_mean_absolute_error: 0.0572 - dense_11_mean_absolute_error: 0.0628 - dense_12_mean_absolute_error: 0.0662 - val_loss: 0.4117 - val_dense_5_loss: 0.0038 - val_dense_6_loss: 0.0031 - val_dense_7_loss: 0.0021 - val_dense_8_loss: 0.0021 - val_dense_9_loss: 0.0029 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0040 - val_dense_12_loss: 0.0055 - val_dense_5_mean_absolute_error: 0.0543 - val_dense_6_mean_absolute_error: 0.0492 - val_dense_7_mean_absolute_error: 0.0382 - val_dense_8_mean_absolute_error: 0.0446 - val_dense_9_mean_absolute_error: 0.0450 - val_dense_10_mean_absolute_error: 0.0486 - val_dense_11_mean_absolute_error: 0.0570 - val_dense_12_mean_absolute_error: 0.0692
# Epoch 42/100
# ...
# Epoch 88/100
# 44/44 [==============================] - 23s 514ms/step - loss: 0.0451 - dense_5_loss: 0.0028 - dense_6_loss: 0.0030 - dense_7_loss: 0.0028 - dense_8_loss: 0.0034 - dense_9_loss: 0.0032 - dense_10_loss: 0.0036 - dense_11_loss: 0.0039 - dense_12_loss: 0.0042 - dense_5_mean_absolute_error: 0.0444 - dense_6_mean_absolute_error: 0.0468 - dense_7_mean_absolute_error: 0.0439 - dense_8_mean_absolute_error: 0.0476 - dense_9_mean_absolute_error: 0.0482 - dense_10_mean_absolute_error: 0.0513 - dense_11_mean_absolute_error: 0.0550 - dense_12_mean_absolute_error: 0.0595 - val_loss: 0.0424 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 0.0023 - val_dense_7_loss: 0.0019 - val_dense_8_loss: 0.0018 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0032 - val_dense_11_loss: 0.0042 - val_dense_12_loss: 0.0053 - val_dense_5_mean_absolute_error: 0.0419 - val_dense_6_mean_absolute_error: 0.0377 - val_dense_7_mean_absolute_error: 0.0362 - val_dense_8_mean_absolute_error: 0.0347 - val_dense_9_mean_absolute_error: 0.0450 - val_dense_10_mean_absolute_error: 0.0464 - val_dense_11_mean_absolute_error: 0.0558 - val_dense_12_mean_absolute_error: 0.0643
# Epoch 89/100
# 44/44 [==============================] - 23s 517ms/step - loss: 0.0439 - dense_5_loss: 0.0028 - dense_6_loss: 0.0030 - dense_7_loss: 0.0027 - dense_8_loss: 0.0033 - dense_9_loss: 0.0033 - dense_10_loss: 0.0036 - dense_11_loss: 0.0039 - dense_12_loss: 0.0042 - dense_5_mean_absolute_error: 0.0441 - dense_6_mean_absolute_error: 0.0452 - dense_7_mean_absolute_error: 0.0427 - dense_8_mean_absolute_error: 0.0467 - dense_9_mean_absolute_error: 0.0473 - dense_10_mean_absolute_error: 0.0496 - dense_11_mean_absolute_error: 0.0536 - dense_12_mean_absolute_error: 0.0592 - val_loss: 0.0401 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0019 - val_dense_8_loss: 0.0018 - val_dense_9_loss: 0.0028 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0038 - val_dense_12_loss: 0.0048 - val_dense_5_mean_absolute_error: 0.0379 - val_dense_6_mean_absolute_error: 0.0373 - val_dense_7_mean_absolute_error: 0.0329 - val_dense_8_mean_absolute_error: 0.0330 - val_dense_9_mean_absolute_error: 0.0390 - val_dense_10_mean_absolute_error: 0.0430 - val_dense_11_mean_absolute_error: 0.0512 - val_dense_12_mean_absolute_error: 0.0612
# Epoch 90/100
# 44/44 [==============================] - 23s 519ms/step - loss: 0.0432 - dense_5_loss: 0.0027 - dense_6_loss: 0.0031 - dense_7_loss: 0.0027 - dense_8_loss: 0.0033 - dense_9_loss: 0.0033 - dense_10_loss: 0.0037 - dense_11_loss: 0.0039 - dense_12_loss: 0.0042 - dense_5_mean_absolute_error: 0.0445 - dense_6_mean_absolute_error: 0.0473 - dense_7_mean_absolute_error: 0.0432 - dense_8_mean_absolute_error: 0.0480 - dense_9_mean_absolute_error: 0.0487 - dense_10_mean_absolute_error: 0.0512 - dense_11_mean_absolute_error: 0.0553 - dense_12_mean_absolute_error: 0.0594 - val_loss: 0.0414 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0019 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0044 - val_dense_12_loss: 0.0057 - val_dense_5_mean_absolute_error: 0.0415 - val_dense_6_mean_absolute_error: 0.0392 - val_dense_7_mean_absolute_error: 0.0354 - val_dense_8_mean_absolute_error: 0.0354 - val_dense_9_mean_absolute_error: 0.0455 - val_dense_10_mean_absolute_error: 0.0482 - val_dense_11_mean_absolute_error: 0.0591 - val_dense_12_mean_absolute_error: 0.0680
# Epoch 91/100
# 44/44 [==============================] - 23s 514ms/step - loss: 0.0423 - dense_5_loss: 0.0028 - dense_6_loss: 0.0030 - dense_7_loss: 0.0027 - dense_8_loss: 0.0033 - dense_9_loss: 0.0033 - dense_10_loss: 0.0037 - dense_11_loss: 0.0038 - dense_12_loss: 0.0042 - dense_5_mean_absolute_error: 0.0447 - dense_6_mean_absolute_error: 0.0473 - dense_7_mean_absolute_error: 0.0436 - dense_8_mean_absolute_error: 0.0481 - dense_9_mean_absolute_error: 0.0483 - dense_10_mean_absolute_error: 0.0518 - dense_11_mean_absolute_error: 0.0544 - dense_12_mean_absolute_error: 0.0604 - val_loss: 0.0400 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0020 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0032 - val_dense_11_loss: 0.0041 - val_dense_12_loss: 0.0052 - val_dense_5_mean_absolute_error: 0.0444 - val_dense_6_mean_absolute_error: 0.0375 - val_dense_7_mean_absolute_error: 0.0365 - val_dense_8_mean_absolute_error: 0.0348 - val_dense_9_mean_absolute_error: 0.0441 - val_dense_10_mean_absolute_error: 0.0447 - val_dense_11_mean_absolute_error: 0.0533 - val_dense_12_mean_absolute_error: 0.0629
# Epoch 92/100
# 44/44 [==============================] - 23s 520ms/step - loss: 0.0410 - dense_5_loss: 0.0027 - dense_6_loss: 0.0030 - dense_7_loss: 0.0026 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0036 - dense_11_loss: 0.0037 - dense_12_loss: 0.0041 - dense_5_mean_absolute_error: 0.0428 - dense_6_mean_absolute_error: 0.0454 - dense_7_mean_absolute_error: 0.0421 - dense_8_mean_absolute_error: 0.0460 - dense_9_mean_absolute_error: 0.0467 - dense_10_mean_absolute_error: 0.0497 - dense_11_mean_absolute_error: 0.0523 - dense_12_mean_absolute_error: 0.0577 - val_loss: 0.0381 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 0.0025 - val_dense_7_loss: 0.0019 - val_dense_8_loss: 0.0018 - val_dense_9_loss: 0.0027 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0038 - val_dense_12_loss: 0.0050 - val_dense_5_mean_absolute_error: 0.0381 - val_dense_6_mean_absolute_error: 0.0402 - val_dense_7_mean_absolute_error: 0.0338 - val_dense_8_mean_absolute_error: 0.0343 - val_dense_9_mean_absolute_error: 0.0388 - val_dense_10_mean_absolute_error: 0.0454 - val_dense_11_mean_absolute_error: 0.0532 - val_dense_12_mean_absolute_error: 0.0657
# Epoch 93/100
# 44/44 [==============================] - 23s 514ms/step - loss: 0.0403 - dense_5_loss: 0.0027 - dense_6_loss: 0.0029 - dense_7_loss: 0.0026 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0037 - dense_11_loss: 0.0037 - dense_12_loss: 0.0041 - dense_5_mean_absolute_error: 0.0432 - dense_6_mean_absolute_error: 0.0448 - dense_7_mean_absolute_error: 0.0419 - dense_8_mean_absolute_error: 0.0461 - dense_9_mean_absolute_error: 0.0464 - dense_10_mean_absolute_error: 0.0506 - dense_11_mean_absolute_error: 0.0525 - dense_12_mean_absolute_error: 0.0580 - val_loss: 0.0381 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 0.0025 - val_dense_7_loss: 0.0019 - val_dense_8_loss: 0.0018 - val_dense_9_loss: 0.0028 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0051 - val_dense_5_mean_absolute_error: 0.0394 - val_dense_6_mean_absolute_error: 0.0375 - val_dense_7_mean_absolute_error: 0.0337 - val_dense_8_mean_absolute_error: 0.0337 - val_dense_9_mean_absolute_error: 0.0393 - val_dense_10_mean_absolute_error: 0.0442 - val_dense_11_mean_absolute_error: 0.0535 - val_dense_12_mean_absolute_error: 0.0644
# Epoch 94/100
# 44/44 [==============================] - 22s 510ms/step - loss: 0.0392 - dense_5_loss: 0.0027 - dense_6_loss: 0.0029 - dense_7_loss: 0.0026 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0036 - dense_11_loss: 0.0037 - dense_12_loss: 0.0039 - dense_5_mean_absolute_error: 0.0427 - dense_6_mean_absolute_error: 0.0451 - dense_7_mean_absolute_error: 0.0413 - dense_8_mean_absolute_error: 0.0460 - dense_9_mean_absolute_error: 0.0465 - dense_10_mean_absolute_error: 0.0493 - dense_11_mean_absolute_error: 0.0519 - dense_12_mean_absolute_error: 0.0569 - val_loss: 0.0373 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0020 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0029 - val_dense_10_loss: 0.0030 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0050 - val_dense_5_mean_absolute_error: 0.0409 - val_dense_6_mean_absolute_error: 0.0365 - val_dense_7_mean_absolute_error: 0.0350 - val_dense_8_mean_absolute_error: 0.0340 - val_dense_9_mean_absolute_error: 0.0435 - val_dense_10_mean_absolute_error: 0.0436 - val_dense_11_mean_absolute_error: 0.0516 - val_dense_12_mean_absolute_error: 0.0621
# Epoch 95/100
# 44/44 [==============================] - 23s 517ms/step - loss: 0.0392 - dense_5_loss: 0.0027 - dense_6_loss: 0.0029 - dense_7_loss: 0.0026 - dense_8_loss: 0.0034 - dense_9_loss: 0.0033 - dense_10_loss: 0.0037 - dense_11_loss: 0.0037 - dense_12_loss: 0.0040 - dense_5_mean_absolute_error: 0.0448 - dense_6_mean_absolute_error: 0.0461 - dense_7_mean_absolute_error: 0.0428 - dense_8_mean_absolute_error: 0.0479 - dense_9_mean_absolute_error: 0.0483 - dense_10_mean_absolute_error: 0.0511 - dense_11_mean_absolute_error: 0.0532 - dense_12_mean_absolute_error: 0.0578 - val_loss: 0.0365 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 0.0023 - val_dense_7_loss: 0.0020 - val_dense_8_loss: 0.0018 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0050 - val_dense_5_mean_absolute_error: 0.0405 - val_dense_6_mean_absolute_error: 0.0358 - val_dense_7_mean_absolute_error: 0.0341 - val_dense_8_mean_absolute_error: 0.0341 - val_dense_9_mean_absolute_error: 0.0438 - val_dense_10_mean_absolute_error: 0.0453 - val_dense_11_mean_absolute_error: 0.0538 - val_dense_12_mean_absolute_error: 0.0624
# Epoch 96/100
# 44/44 [==============================] - 23s 519ms/step - loss: 0.0383 - dense_5_loss: 0.0027 - dense_6_loss: 0.0029 - dense_7_loss: 0.0027 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0035 - dense_11_loss: 0.0037 - dense_12_loss: 0.0040 - dense_5_mean_absolute_error: 0.0435 - dense_6_mean_absolute_error: 0.0447 - dense_7_mean_absolute_error: 0.0423 - dense_8_mean_absolute_error: 0.0466 - dense_9_mean_absolute_error: 0.0470 - dense_10_mean_absolute_error: 0.0497 - dense_11_mean_absolute_error: 0.0532 - dense_12_mean_absolute_error: 0.0582 - val_loss: 0.0358 - val_dense_5_loss: 0.0029 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0018 - val_dense_8_loss: 0.0018 - val_dense_9_loss: 0.0028 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0051 - val_dense_5_mean_absolute_error: 0.0384 - val_dense_6_mean_absolute_error: 0.0378 - val_dense_7_mean_absolute_error: 0.0332 - val_dense_8_mean_absolute_error: 0.0335 - val_dense_9_mean_absolute_error: 0.0394 - val_dense_10_mean_absolute_error: 0.0435 - val_dense_11_mean_absolute_error: 0.0520 - val_dense_12_mean_absolute_error: 0.0635
# Epoch 97/100
# 44/44 [==============================] - 23s 515ms/step - loss: 0.0375 - dense_5_loss: 0.0026 - dense_6_loss: 0.0029 - dense_7_loss: 0.0026 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0036 - dense_11_loss: 0.0036 - dense_12_loss: 0.0039 - dense_5_mean_absolute_error: 0.0417 - dense_6_mean_absolute_error: 0.0441 - dense_7_mean_absolute_error: 0.0409 - dense_8_mean_absolute_error: 0.0457 - dense_9_mean_absolute_error: 0.0464 - dense_10_mean_absolute_error: 0.0490 - dense_11_mean_absolute_error: 0.0514 - dense_12_mean_absolute_error: 0.0565 - val_loss: 0.0355 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0019 - val_dense_8_loss: 0.0018 - val_dense_9_loss: 0.0028 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0051 - val_dense_5_mean_absolute_error: 0.0381 - val_dense_6_mean_absolute_error: 0.0356 - val_dense_7_mean_absolute_error: 0.0334 - val_dense_8_mean_absolute_error: 0.0327 - val_dense_9_mean_absolute_error: 0.0395 - val_dense_10_mean_absolute_error: 0.0437 - val_dense_11_mean_absolute_error: 0.0515 - val_dense_12_mean_absolute_error: 0.0625
# Epoch 98/100
# 44/44 [==============================] - 23s 524ms/step - loss: 0.0371 - dense_5_loss: 0.0027 - dense_6_loss: 0.0030 - dense_7_loss: 0.0026 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0036 - dense_11_loss: 0.0036 - dense_12_loss: 0.0039 - dense_5_mean_absolute_error: 0.0433 - dense_6_mean_absolute_error: 0.0455 - dense_7_mean_absolute_error: 0.0429 - dense_8_mean_absolute_error: 0.0464 - dense_9_mean_absolute_error: 0.0475 - dense_10_mean_absolute_error: 0.0503 - dense_11_mean_absolute_error: 0.0524 - dense_12_mean_absolute_error: 0.0568 - val_loss: 0.0357 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 0.0027 - val_dense_7_loss: 0.0020 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0029 - val_dense_10_loss: 0.0033 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0050 - val_dense_5_mean_absolute_error: 0.0425 - val_dense_6_mean_absolute_error: 0.0434 - val_dense_7_mean_absolute_error: 0.0385 - val_dense_8_mean_absolute_error: 0.0361 - val_dense_9_mean_absolute_error: 0.0414 - val_dense_10_mean_absolute_error: 0.0467 - val_dense_11_mean_absolute_error: 0.0534 - val_dense_12_mean_absolute_error: 0.0642
# Epoch 99/100
# 44/44 [==============================] - 23s 515ms/step - loss: 0.0366 - dense_5_loss: 0.0026 - dense_6_loss: 0.0029 - dense_7_loss: 0.0026 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0036 - dense_11_loss: 0.0036 - dense_12_loss: 0.0040 - dense_5_mean_absolute_error: 0.0423 - dense_6_mean_absolute_error: 0.0446 - dense_7_mean_absolute_error: 0.0414 - dense_8_mean_absolute_error: 0.0467 - dense_9_mean_absolute_error: 0.0468 - dense_10_mean_absolute_error: 0.0502 - dense_11_mean_absolute_error: 0.0521 - dense_12_mean_absolute_error: 0.0580 - val_loss: 0.0349 - val_dense_5_loss: 0.0030 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0019 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0029 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0052 - val_dense_5_mean_absolute_error: 0.0390 - val_dense_6_mean_absolute_error: 0.0357 - val_dense_7_mean_absolute_error: 0.0339 - val_dense_8_mean_absolute_error: 0.0332 - val_dense_9_mean_absolute_error: 0.0411 - val_dense_10_mean_absolute_error: 0.0446 - val_dense_11_mean_absolute_error: 0.0537 - val_dense_12_mean_absolute_error: 0.0654
# Epoch 100/100
# 44/44 [==============================] - 22s 510ms/step - loss: 0.0362 - dense_5_loss: 0.0026 - dense_6_loss: 0.0029 - dense_7_loss: 0.0026 - dense_8_loss: 0.0033 - dense_9_loss: 0.0032 - dense_10_loss: 0.0036 - dense_11_loss: 0.0038 - dense_12_loss: 0.0039 - dense_5_mean_absolute_error: 0.0424 - dense_6_mean_absolute_error: 0.0445 - dense_7_mean_absolute_error: 0.0413 - dense_8_mean_absolute_error: 0.0465 - dense_9_mean_absolute_error: 0.0468 - dense_10_mean_absolute_error: 0.0497 - dense_11_mean_absolute_error: 0.0538 - dense_12_mean_absolute_error: 0.0576 - val_loss: 0.0345 - val_dense_5_loss: 0.0031 - val_dense_6_loss: 0.0024 - val_dense_7_loss: 0.0020 - val_dense_8_loss: 0.0019 - val_dense_9_loss: 0.0030 - val_dense_10_loss: 0.0031 - val_dense_11_loss: 0.0039 - val_dense_12_loss: 0.0049 - val_dense_5_mean_absolute_error: 0.0423 - val_dense_6_mean_absolute_error: 0.0372 - val_dense_7_mean_absolute_error: 0.0372 - val_dense_8_mean_absolute_error: 0.0344 - val_dense_9_mean_absolute_error: 0.0440 - val_dense_10_mean_absolute_error: 0.0436 - val_dense_11_mean_absolute_error: 0.0516 - val_dense_12_mean_absolute_error: 0.0606

# %%
model.save('forecasting_models/bon3h_sat')

# %%
model.evaluate(x = [te_inputs[key] for key in te_inputs.keys()],
               y = [test_output_15,test_output_30,test_output_45,test_output_60,
                    test_output_90,test_output_120,test_output_150,test_output_180]
              )
# Out:
# 50/50 [==============================] - 21s 161ms/step - loss: 0.0492 - dense_5_loss: 0.0040 - dense_6_loss: 0.0039 - dense_7_loss: 0.0043 - dense_8_loss: 0.0043 - dense_9_loss: 0.0048 - dense_10_loss: 0.0049 - dense_11_loss: 0.0061 - dense_12_loss: 0.0066 - dense_5_mean_absolute_error: 0.0568 - dense_6_mean_absolute_error: 0.0561 - dense_7_mean_absolute_error: 0.0588 - dense_8_mean_absolute_error: 0.0586 - dense_9_mean_absolute_error: 0.0634 - dense_10_mean_absolute_error: 0.0638 - dense_11_mean_absolute_error: 0.0699 - dense_12_mean_absolute_error: 0.0773
# [0.04916061833500862,
#  0.003952272702008486,
#  0.003921042196452618,
#  0.004338221624493599,
#  0.004320184234529734,
#  0.004849492106586695,
#  0.004910978022962809,
#  0.006067818962037563,
#  0.006605507340282202,
#  0.05683237314224243,
#  0.0561472624540329,
#  0.058826152235269547,
#  0.058626849204301834,
#  0.06337027251720428,
#  0.06378994137048721,
#  0.06986194849014282,
#  0.0773223415017128]

# %%
y_predict = model.predict(x = [te_inputs[key] for key in te_inputs.keys()])

# %%
from sklearn import metrics
def rmse_fs(y,test_index):
    ns_csi_00 = df_ghi.loc[te_index_00,'CSI'].values.reshape(len(te_index_00),1)
    ns_clear = df_ghi.loc[test_index,'ghics_rest'].values.reshape(len(test_index),1)
    test_output = df_ghi.loc[test_index,'CSI'].values.reshape(len(test_index),1)
    rmse1 = np.sqrt(metrics.mean_squared_error(y*ns_clear,test_output*ns_clear))
    nrmse1 = rmse1/np.mean(test_output*ns_clear)
    rmse0 = np.sqrt(metrics.mean_squared_error(ns_csi_00*ns_clear,test_output*ns_clear))
    nrmse0 = rmse0/np.mean(test_output*ns_clear)
    mbe1 = np.mean([x-y for x,y in zip(y*ns_clear,test_output*ns_clear)])
    nmbe1 = mbe1/np.mean(test_output*ns_clear)
    mbe0 = np.mean([x-y for x,y in zip(ns_csi_00*ns_clear,test_output*ns_clear)])
    nmbe0 = mbe0/np.mean(test_output*ns_clear)
    fs = 1-rmse1/rmse0
    return nrmse1,nrmse0,nmbe1,nmbe0,fs

# %%
tests = [te_index15,te_index30,te_index45,te_index60,te_index90,te_index120,te_index150,te_index180]
for x,y in zip([y_predict[i] for i in range(8)],tests):
    print(rmse_fs(x,y))
# Out:
# (0.09026778316668667, 0.0943048664610409, 0.004180362892203226, -0.0017308516233758577, 0.04280885436619575)
# (0.0910815847235794, 0.10322693889593071, 0.0029283549508024825, -0.003434878447254541, 0.11765682778403197)
# (0.09621088715936467, 0.11110217813365518, 0.007185694156166099, -0.0045245640688892814, 0.13403239454384397)
# (0.0966692483972678, 0.11275918195468787, 0.005349091802615056, -0.005058630691549471, 0.14269289009107733)
# (0.10252667003028117, 0.1238699408667341, 0.008971434501014956, -0.005347537709640315, 0.17230387523487367)
# (0.10398942567471166, 0.13456515288358112, 0.004667806989012884, -0.0033561988355503445, 0.22721876023372867)
# (0.11219039118933063, 0.14080582724103732, 0.009269337413590328, 0.001953408683544789, 0.2032262201955718)
# (0.1204590024266627, 0.14965130424717635, -0.002609298907080907, 0.002502101724075544, 0.19506880990691045)
